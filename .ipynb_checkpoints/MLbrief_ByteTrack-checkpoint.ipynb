# %% [markdown]
# # MLbriefs: ByteTrack

# %%
# !ls
# Out:
# ByteTrack  ByteTrack.ipynb  ipol.txt  MLbrief_ByteTrack.ipynb  requirements.txt

# %%
# %cd ByteTrack
# Out:
# /home/abenmabrouk/Documents/Projects/MOT/MLbriefs/ByteTrack/ByteTrack

# %%
# !ls
# Out:
# assets	    log.txt		       out7.webm	 setup.py
# build	    MLbrief_ByteTrack_demo.sh  out8.webm	 tools
# datasets    out2.webm		       out.webm		 tutorials
# deploy	    out3.webm		       pretrained	 videos
# Dockerfile  out4.webm		       README.md	 yolox
# exps	    out5.webm		       requirements.txt  yolox.egg-info
# LICENSE     out6.webm		       setup.cfg	 YOLOX_outputs

# %%
# !sh MLbrief_ByteTrack_demo.sh ./videos/MOT17-02-DPM_lf_2.mp4 output10.mp4
# Out:
# found=YOLOX_outputs/yolox_x_mix_det/track_vis/2022_04_05_15_28_01/MOT17-02-DPM_lf_2.mp4
# ffmpeg version n5.0 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 11.2.0 (GCC)
# ...
